# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_titanic = pd.read_csv('train.csv') #reads the data
df_titanic.info() #shows information about the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Question 1

# %%
df_titanic[:6] #shows the first 6 data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# # Question 2

# %%
df_titanic[-6:] #shows the last 6 data

# %% [markdown]
# # Question 3

# %%
list(df_titanic.columns) #shows the column titles

# %% [markdown]
# # Question 4

# %%
df_titanic.shape[0] #shows the passengers size of the dataset

# %% [markdown]
# # Question 5

# %%
df_titanic.isna().sum() #shows the number of NaN values of the all columns

# %%
df_titanic["Age"].isna().sum() #shows the number of NaN values of the age column

# %%
df_titanic["Cabin"].isna().sum() #shows the number of NaN values of the cabin column

# %%
df_titanic["Embarked"].isna().sum() #shows the number of NaN values of the embarked column

# %% [markdown]
# Age column has 177 NaN values, cabin column has 687 NaN values, embarked column has 2 NaN values.

# %% [markdown]
# # Question 6

# %%
df_titanic["Age"].min() #shows the age of the youngest passenger

# %% [markdown]
# # Question 7

# %%
df_titanic[df_titanic["Survived"]==1]["Age"].min() #shows the age of the youngest passenger who survived

# %% [markdown]
# # Question 8

# %%
df_titanic["Fare"].mean() #shows the average fare

# %% [markdown]
# # Question 9

# %%
df_titanic[df_titanic["Survived"]==1]["Age"].max() #shows the age of the oldest passenger who survived
# Out:
# np.float64(80.0)

# %% [markdown]
# # Question 10

# %%
df_titanic[(df_titanic["Survived"]==1) & (df_titanic["Sex"]=="female")]["Age"].max() #shows the age of the oldest female passenger who survived
# Out:
# np.float64(63.0)

# %% [markdown]
# # Question 11

# %%
df_titanic[(df_titanic["Age"] < 10) & (df_titanic["Parch"]==0)]

# %% [markdown]
# There was a child under the age of 10 traveling without their parents. This may be because there might be a mistake in the data or the baby may have boarded the ship with the babysitter.

# %% [markdown]
# # Question 12

# %%
df_titanic["SibSp"].max() #shows the number of siblings of the passenger who has the highest number of siblings

# %% [markdown]
# # Question 13 - 14

# %%
df_titanic["Title"] = df_titanic["Name"].apply(lambda x: x.split(',')[1].split(" ")[1]) # split name to get titles
df_titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr.
# 1      0          PC 17599  71.2833   C85        C   Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss.
# 3      0            113803  53.1000  C123        S   Mrs.
# ...

# %%
df_titanic['Title'].mode()
# Out:
# 0    Mr.
# Name: Title, dtype: object

# %%
df_titanic['Title'].nunique()
# Out:
# 17

# %% [markdown]
# The most commonly used titleis Mr. and there are 17 distinct titles are used.

# %% [markdown]
# # Question 15

# %%
df_titanic["Age"].mean()
